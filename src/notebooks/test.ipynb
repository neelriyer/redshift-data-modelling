# %% [markdown]
# ### Import dependencies

# %%
import configparser

config = configparser.ConfigParser()
config.read('../dwh.cfg')
# Out:
# ['../dwh.cfg']

# %% [markdown]
# ### Connect to redshift

# %%
# %load_ext sql

HOST = config.get('CLUSTER', 'HOST')
DB_NAME =  config.get('CLUSTER', 'DB_NAME')
DB_USER = config.get('CLUSTER', 'DB_USER')
DB_PASSWORD = config.get('CLUSTER', 'DB_PASSWORD')
DB_PORT = config.get('CLUSTER', 'DB_PORT')

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, HOST, DB_PORT, DB_NAME)

print(conn_string)
# %sql $conn_string
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# postgresql://student:Password123@redshift-udacity.c83pb22gsa6f.us-west-2.redshift.amazonaws.com:5439/songdb

# %%
# %sql SELECT COUNT(*) FROM songplays;
# Out:
#  * postgresql://student:***@redshift-udacity.c83pb22gsa6f.us-west-2.redshift.amazonaws.com:5439/songdb
# 1 rows affected.
# [(333,)]

# %%
# %sql SELECT * FROM songplays LIMIT 10;
# Out:
#  * postgresql://student:***@redshift-udacity.c83pb22gsa6f.us-west-2.redshift.amazonaws.com:5439/songdb
# 10 rows affected.
# [(0, datetime.datetime(2018, 11, 14, 15, 14, 54), '25', 'paid', 'SOVXAXI12A8C1383D9', 'ARY65231187FB46283', 534, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (64, datetime.datetime(2018, 11, 26, 18, 25, 34), '92', 'free', 'SONQBUB12A6D4F8ED0', 'ARFCUN31187B9AD578', 938, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (128, datetime.datetime(2018, 11, 27, 18, 4, 57), '49', 'paid', 'SOHGMJH12AB0187130', 'ARDQ9AP1187B9BA3F6', 987, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (192, datetime.datetime(2018, 11, 13, 8, 30, 1), '25', 'paid', 'SODWLOQ12AB017EC73', 'AR4SRB61187FB5538F', 442, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (256, datetime.datetime(2018, 11, 7, 15, 41, 10), '15', 'paid', 'SOWEUOO12A6D4F6D0C', 'ARQUMH41187B9AF699', 221, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (43, datetime.datetime(2018, 11, 11, 15, 0, 37), '67', 'free', 'SOCHRXB12A8AE48069', 'ARTDQRC1187FB4EFD4', 414, 'Nashville-Davidson--Murfreesboro--Franklin, TN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (107, datetime.datetime(2018, 11, 17, 15, 51, 53), '73', 'paid', 'SODKJWI12A8151BD74', 'ARM0P6Z1187FB4D466', 518, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (171, datetime.datetime(2018, 11, 28, 7, 11, 30), '58', 'paid', 'SOTSQDK12AB0184D15', 'ARPTKAK1187FB5308A', 887, 'Augusta-Richmond County, GA-SC', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (235, datetime.datetime(2018, 11, 9, 19, 34, 24), '80', 'paid', 'SOWFHCO12AB0189063', 'ARFIU2R1187B9927F9', 434, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (22, datetime.datetime(2018, 11, 29, 20, 21, 41), '49', 'paid', 'SOABIXP12A8C135F75', 'AR15DJQ1187FB5910C', 1041, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')]

# %%
# %%sql
# SELECT users.first_name, users.last_name, COUNT(songs.title) as songs_listened
# FROM songplays
# JOIN songs ON (songplays.song_id = songs.song_id)
# JOIN artists ON (songplays.artist_id = artists.artist_id)
# JOIN users ON (songplays.user_id = users.user_id)
# GROUP BY users.first_name, users.last_name
# ORDER BY songs_listened DESC;
# Out:
#  * postgresql://student:***@redshift-udacity.c83pb22gsa6f.us-west-2.redshift.amazonaws.com:5439/songdb
# 57 rows affected.
# [('Chloe', 'Cuevas', 51),
#  ('Tegan', 'Levine', 36),
#  ('Kate', 'Harrell', 33),
#  ('Aleena', 'Kirby', 24),
#  ('Jacob', 'Klein', 23),
#  ('Mohammad', 'Rodriguez', 18),
#  ('Lily', 'Koch', 15),
#  ('Matthew', 'Jones', 15),
#  ('Layla', 'Griffin', 15),
#  ('Jacqueline', 'Lynch', 15),
#  ('Jayden', 'Graves', 10),
#  ('Emily', 'Benson', 10),
#  ('Sara', 'Johnson', 9),
#  ('Avery', 'Watkins', 8),
#  ('Kinsley', 'Young', 7),
#  ('Harper', 'Barrett', 7),
#  ('Ava', 'Robinson', 6),
#  ('Rylan', 'George', 6),
#  ('Colm', 'Santana', 4),
#  ('Adler', 'Barrera', 4),
#  ('Stefany', 'White', 3),
#  ('Anabelle', 'Simpson', 3),
#  ('Aiden', 'Hess', 3),
#  ('Kevin', 'Arellano', 3),
#  ('Tucker', 'Garrison', 3),
#  ('Celeste', 'Williams', 3),
#  ('Hayden', 'Brock', 3),
#  ('Ryann', 'Smith', 3),
#  ('Avery', 'Martinez', 3),
#  ('Jizelle', 'Benjamin', 3),
#  ('Kaylee', 'Summers', 3),
#  ('Austin', 'Rosales', 3),
#  ('Jaleah', 'Hayes', 2),
#  ('Jayden', 'Fox', 2),
#  ('Kaleb', 'Cook', 2),
#  ('Chloe', 'Roth', 2),
#  ('Katherine', 'Gay', 2),
#  ('Theodore', 'Smith', 2),
#  ('Bronson', 'Harris', 2),
#  ('Samuel', 'Gonzalez', 1),
#  ('Morris', 'Gilmore', 1),
#  ('Sylvie', 'Cruz', 1),
#  ('Noah', 'Chavez', 1),
#  ('Lily', 'Burns', 1),
#  ('Joseph', 'Gutierrez', 1),
#  ('Sienna', 'Colon', 1),
#  ('Ryan', 'Smith', 1),
#  ('Ayla', 'Johnson', 1),
#  ('Ayleen', 'Wise', 1),
#  ('Cecilia', 'Owens', 1),
#  ('Jordyn', 'Powell', 1),
#  ('Martin', 'Johnson', 1),
#  ('Jayden', 'Bell', 1),
#  ('Connar', 'Moreno', 1),
#  ('Brantley', 'West', 1),
#  ('Andrea', 'Butler', 1),
#  ('Molly', 'Taylor', 1)]

# %%
# %%sql
# SELECT CONCAT(users.first_name, users.last_name) as user, songs.title as song, artists.name as artist, time.day, time.month, time.year
# FROM songplays
# JOIN songs ON (songplays.song_id = songs.song_id)
# JOIN artists ON (songplays.artist_id = artists.artist_id)
# JOIN users ON (songplays.user_id = users.user_id)
# JOIN time ON (songplays.start_time = time.start_time)
# LIMIT 10;
# Out:
#  * postgresql://student:***@redshift-udacity.c83pb22gsa6f.us-west-2.redshift.amazonaws.com:5439/songdb
# 10 rows affected.
# [('JacobKlein', 'Angie (1993 Digital Remaster)', 'The Rolling Stones', 24, 11, 2018),
#  ('MohammadRodriguez', "What It Ain't", 'Josh Turner', 26, 11, 2018),
#  ('JacquelineLynch', 'From The Ritz To The Rubble', 'Richard Hawley And Death Ramps_ Arctic Monkeys', 24, 11, 2018),
#  ('JacquelineLynch', 'From The Ritz To The Rubble', 'Arctic Monkeys', 24, 11, 2018),
#  ('KateHarrell', 'Club Soda (Album)', 'Ghostland Observatory', 21, 11, 2018),
#  ('JacquelineLynch', 'Yippiyo-Ay', 'The Presets', 24, 11, 2018),
#  ('AleenaKirby', 'Lovefool', 'The Cardigans', 15, 11, 2018),
#  ('BrantleyWest', 'Crawling (Album Version)', 'Linkin Park', 27, 11, 2018),
#  ('AidenHess', 'Fade To Black', 'Metallica', 23, 11, 2018),
#  ('KatherineGay', 'Fake Tales Of San Francisco', 'Richard Hawley And Death Ramps_ Arctic Monkeys', 5, 11, 2018)]
